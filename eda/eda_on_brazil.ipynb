# %%
from skimpy import skim
# data manipulation
import pandas as pd
import numpy as np

# data viz
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# # apply some cool styling
# plt.style.use("ggplot")
# rcParams['figure.figsize'] = (12, 6)

# get all data from the folder named brazil in seperated df, and named the df as df_{customer} or df_{order_item} etc
df_customer = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_customers_dataset.csv')
df_geolocation = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_geolocation_dataset.csv')
df_order_items = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_order_items_dataset.csv')
df_order_payments = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_order_payments_dataset.csv') 
df_order_reviews = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_order_reviews_dataset.csv')
df_orders = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_orders_dataset.csv')
df_products = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_products_dataset.csv')
df_sellers = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/olist_sellers_dataset.csv')
df_product_category_name_translation = pd.read_csv('/Users/alvin_lau/Desktop/xchange-recsys/dataset/brazil/product_category_name_translation.csv')

# %%
print("df name: df_customer")
skim(df_customer)
print("df name: df_geolocation")
skim(df_geolocation)
print("df name: df_order_items")
skim(df_order_items)
print("df name: df_order_payments")
skim(df_order_payments)
print("df name: df_order_reviews")
skim(df_order_reviews)
print("df name: df_orders")
skim(df_orders)
print("df name: df_products")
skim(df_products)
print("df name: df_sellers")
skim(df_sellers)
print("df name: df_product_category_name_translation")
skim(df_product_category_name_translation)
# Out:
# df name: df_customer
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 99441  │ │ string      │ 4     │                                                          │
# │ │ Number of columns │ 5      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...
